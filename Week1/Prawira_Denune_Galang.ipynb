# %% [markdown]
# **PRAWIRA DENUNE GALANG**

# %% [markdown]
# # Task 1. Descriptive Data Analysis

# %% [markdown]
# Use data from the **StudentPerformanceFactors.csv** file with student information.
#
# [Source](https://www.kaggle.com/datasets/lainguyn123/student-performance-factors/code)
#
# It contains the following variables:
#
# | Variable name | Variable description
# |:-------------------:|:------------------:|
# | Hours_Studied | Number of hours spent studying per week |
# | Attendance | Percentage of classes attended |
# | Parental_Involvement | Level of parental involvement in the student's education (Low, Medium, High)|
# | Access_to_Resources | Availability of educational resources (Low, Medium, High)|
# | Extracurricular_Activities | Participation in extracurricular activities (Yes, No).
# | Sleep_Hours | Average number of hours of sleep per night.
# | Previous_Scores |	Scores from previous exams.
# | Motivation_Level |	Student's level of motivation (Low, Medium, High).
# | Internet_Access |	Availability of internet access (Yes, No).
# | Tutoring_Sessions |	Number of tutoring sessions attended per month.
# | Family_Income |	Family income level (Low, Medium, High).
# | Teacher_Quality |	Quality of the teachers (Low, Medium, High).
# | School_Type |	Type of school attended (Public, Private).
# | Peer_Influence |	Influence of peers on academic performance (Positive, Neutral, Negative).
# | Physical_Activity |	Average number of hours of physical activity per week.
# | Learning_Disabilities |	Presence of learning disabilities (Yes, No).
# | Parental_Education_Level |	Highest education level of parents (High School, College, Postgraduate).
# | Distance_from_Home |	Distance from home to school (Near, Moderate, Far).
# | Gender |	Gender of the student (Male, Female).
# | Exam_Score |	Final exam score.

# %% [markdown]
# Please complete the following tasks.

# %% [markdown]
# 1. Describe the dataset (number of observations and variables, missing values, data types, variables’ measurement scale).

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("StudentPerformanceFactors.csv")

# %%
df
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
print (df.isnull().sum())
# Out:
# Hours_Studied                  0
# Attendance                     0
# Parental_Involvement           0
# Access_to_Resources            0
# Extracurricular_Activities     0
# Sleep_Hours                    0
# Previous_Scores                0
# Motivation_Level               0
# Internet_Access                0
# Tutoring_Sessions              0
# Family_Income                  0
# Teacher_Quality               78
# School_Type                    0
# Peer_Influence                 0
# Physical_Activity              0
# Learning_Disabilities          0
# Parental_Education_Level      90
# Distance_from_Home            67
# Gender                         0
# Exam_Score                     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6607 entries, 0 to 6606
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Hours_Studied               6607 non-null   int64
#  1   Attendance                  6607 non-null   int64
#  2   Parental_Involvement        6607 non-null   object
#  3   Access_to_Resources         6607 non-null   object
#  4   Extracurricular_Activities  6607 non-null   object
#  5   Sleep_Hours                 6607 non-null   int64
#  6   Previous_Scores             6607 non-null   int64
#  7   Motivation_Level            6607 non-null   object
#  8   Internet_Access             6607 non-null   object
#  9   Tutoring_Sessions           6607 non-null   int64
#  10  Family_Income               6607 non-null   object
#  11  Teacher_Quality             6529 non-null   object
#  12  School_Type                 6607 non-null   object
# ...

# %%
print(df.dtypes)
# Out:
# Hours_Studied                  int64
# Attendance                     int64
# Parental_Involvement          object
# Access_to_Resources           object
# Extracurricular_Activities    object
# Sleep_Hours                    int64
# Previous_Scores                int64
# Motivation_Level              object
# Internet_Access               object
# Tutoring_Sessions              int64
# Family_Income                 object
# Teacher_Quality               object
# School_Type                   object
# Peer_Influence                object
# Physical_Activity              int64
# Learning_Disabilities         object
# Parental_Education_Level      object
# Distance_from_Home            object
# Gender                        object
# Exam_Score                     int64
# dtype: object

# %%
print(df.shape)
# Out:
# (6607, 20)

# %% [markdown]
# 2. Conduct descriptive analysis of the variables using appropriate analysis methods depending on the type of the variables’ measurement scale (frequency data analysis, pivot tables, central tendency and dispersion measures, variables’ distribution characteristics, graphical data analysis). Interpret the results. Please note that data analysis involves the following steps:
# - research task setting and selection of variables,
# - selection of the appropriate analysis method,
# - calculations,
# - interpretation of results.
#
# For example, I would like to analyze the physical activity of students. I consider the variable "Physical_Activity". Since it has a ratio scale of measurement, for its analysis I will create a histogram and calculate descriptive statistics. Then I will make conclusions based on the calculations.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

display(df['Exam_Score'].describe())
display(df['Hours_Studied'].describe())
display(df['Distance_from_Home'].describe())

#Display
plt.figure(figsize=(8, 5))
sns.histplot(df['Exam_Score'], kde=True)
plt.title('Distribution of Exam Scores')
plt.xlabel('Exam Score')
plt.ylabel('Frequency')
plt.show()

plt.figure(figsize=(8, 5))
sns.histplot(df['Hours_Studied'], kde=True)
plt.title('Hours Studied')
plt.xlabel('Hours Studied')
plt.ylabel('Frequency')
plt.show()

plt.figure(figsize=(8, 5))
sns.histplot(df['Distance_from_Home'], kde=True)
plt.title('Distance from Home')
plt.xlabel('Distance_from_Home')
plt.ylabel('Frequency')
plt.show()



plt.figure(figsize=(8, 5))
sns.boxplot(x='Distance_from_Home', y='Exam_Score', data=df, order=['Near', 'Moderate', 'Far'])
plt.title('Exam Score by Distance from Home')
plt.xlabel('Distance from Home')
plt.ylabel('Exam Score')
plt.show()
display(df.groupby('Distance_from_Home')['Exam_Score'].describe())


plt.figure(figsize=(8, 5))
sns.boxplot(x='Motivation_Level', y='Exam_Score', data=df, order=['Low', 'Medium', 'High'])
plt.title('Exam Score by Motivation Level')
plt.xlabel('Motivation Level')
plt.ylabel('Exam Score')
plt.show()
display(df.groupby('Motivation_Level')['Exam_Score'].describe())

plt.figure(figsize=(8, 5))
sns.scatterplot(x='Hours_Studied', y='Exam_Score', data=df)
plt.title('Exam Score vs. Hours Studied')
plt.xlabel('Hours Studied')
plt.ylabel('Exam Score')
plt.show()
display(df.groupby('Hours_Studied')['Exam_Score'].describe())
# Out:
# count    6607.000000
# mean       67.235659
# std         3.890456
# min        55.000000
# 25%        65.000000
# 50%        67.000000
# 75%        69.000000
# max       101.000000
# Name: Exam_Score, dtype: float64
# count    6607.000000
# mean       19.975329
# std         5.990594
# min         1.000000
# 25%        16.000000
# 50%        20.000000
# 75%        24.000000
# max        44.000000
# Name: Hours_Studied, dtype: float64
# count     6540
# unique       3
# top       Near
# freq      3884
# Name: Distance_from_Home, dtype: object
#                      count       mean       std   min   25%   50%   75%    max
# Distance_from_Home
# Far                  658.0  66.457447  4.144885  56.0  64.0  66.0  68.0   99.0
# Moderate            1998.0  66.981481  3.787304  57.0  65.0  67.0  69.0  101.0
# Near                3884.0  67.512101  3.881533  55.0  65.0  67.0  70.0  100.0
#                    count       mean       std   min   25%   50%   75%    max
# Motivation_Level
# ...

# %% [markdown]
# we divide 44 hours of Hours_Studied to be 3 catagories
# 1. Low (1-14)
# 2. medium (15-29)
# 3. High (30-44)

# %%
bins = [0, 13, 27, 44]
labels = ['1-13', '14-27', '28-44']

df['Hours_Studied_Range'] = pd.cut(df['Hours_Studied'], bins=bins, labels=labels, right=True, include_lowest=True)


mean_exam_by_hours_range = df.groupby('Hours_Studied_Range')['Exam_Score'].mean()


print("Average Exam Scores based on Range of Study Hours:")
print(mean_exam_by_hours_range)
# Out:
# Average Exam Scores based on Range of Study Hours:
# Hours_Studied_Range
# 1-13     64.473398
# 14-27    67.307293
# 28-44    70.444934
# Name: Exam_Score, dtype: float64
# /tmp/ipython-input-438964732.py:7: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mean_exam_by_hours_range = df.groupby('Hours_Studied_Range')['Exam_Score'].mean()

# %%
mean_exam_by_motivation = df.groupby('Motivation_Level')['Exam_Score'].mean()

print("Average Exam_Score base motivation level:")
print(mean_exam_by_motivation)
# Out:
# Average Exam_Score base motivation level:
# Motivation_Level
# High      67.704321
# Low       66.752194
# Medium    67.330648
# Name: Exam_Score, dtype: float64

# %%
mean_exam_by_distance = df.groupby('Distance_from_Home')['Exam_Score'].mean()

print("Average Exam Score base Distance from Home:")
print(mean_exam_by_distance)
# Out:
# Average Exam Score base Distance from Home:
# Distance_from_Home
# Far         66.457447
# Moderate    66.981481
# Near        67.512101
# Name: Exam_Score, dtype: float64

# %% [markdown]
# 1. (Hours Studied) The Squared Correlation (R²) value is approximately 20%. This indicates exam scores can be explained by a linear relationship with hours studied. but hours studied are not the sole determinant of exam scores.
# 2. (Distance from Home) There is a difference in average test scores of about 1.57% between students who live 'Near' compared to those who live 'Far', relative to the overall average test score.
# 3. (Mptivation) There is a difference in average test scores of about 1.42% between students with 'High' motivation compared to those with 'Low' motivation, relative to the overall average test score. Which mean high Motivation have impact on Exam Score but not significant

# %% [markdown]
# ***Conclusion :
# From our analysis, we can understand that hour of studied have significant effect on result of Exam, althought***

# %% [markdown]
# 3. Please answer the questions (you may have already answered some of them in the previous section):
# - What percentage of students are highly motivated?
# - What is the ratio of students with different levels of parental involvement in their education by family income level?
# - Is there a relationship between the number of sleep hours and class attendance (at this stage, we study the relationships based on descriptive data analysis)?
# - How do grades differ for boys and girls living at different distances from school?
# - What are the specific characteristics of distribution of final exam grades?
# - Is there a relationship between the level of students' motivation and the quality of teaching?
# - What are the characteristics of excellent students (please define and describe which students should be classified as excellent)?
# - Which factors are positively correlated with exam results (at this stage, we study the relationships based on descriptive data analysis)?
# - Which variables have a distribution close to normal, explain your answer?
# - Which metric variables have an asymmetry in the distribution of their values?

# %% [markdown]
# **1. Percentage of students are highly motivated?**

# %%
print("Counts of students by Motivation_Level:")
display(df['Motivation_Level'].value_counts())

print("\nPercentage of students by Motivation_Level:")
display(df['Motivation_Level'].value_counts(normalize=True) * 100)

plt.figure(figsize=(8, 5))
sns.countplot(x='Motivation_Level', data=df, order=['Low', 'Medium', 'High'])
plt.title('Distribution of Student Motivation Levels')
plt.xlabel('Motivation Level')
plt.ylabel('Number of Students')
plt.show()
# Out:
# Counts of students by Motivation_Level:
# Motivation_Level
# Medium    3351
# Low       1937
# High      1319
# Name: count, dtype: int64
# Percentage of students by Motivation_Level:
# Motivation_Level
# Medium    50.718934
# Low       29.317391
# High      19.963675
# Name: proportion, dtype: float64

# %% [markdown]
# **2. Ratio of students with different levels of parental involvement in their education by family income level**

# %%
print("Frequency table of Parental_Involvement by Family_Income:")
cross_tab = pd.crosstab(df['Parental_Involvement'], df['Family_Income'])
display(cross_tab)

print("\nProportion of Parental_Involvement within each Family_Income level:")
cross_tab_prop = pd.crosstab(df['Parental_Involvement'], df['Family_Income'], normalize='columns')
display(cross_tab_prop)


cross_tab_prop.T.plot(kind='bar', stacked=True, figsize=(10, 7))
plt.title('Proportion of Parental Involvement by Family Income Level')
plt.xlabel('Family Income Level')
plt.ylabel('Proportion of Students')
plt.xticks(rotation=0)
plt.legend(title='Parental Involvement', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# Frequency table of Parental_Involvement by Family_Income:
# Family_Income         High   Low  Medium
# Parental_Involvement
# High                   369   768     771
# Low                    251   571     515
# Medium                 649  1333    1380
# Proportion of Parental_Involvement within each Family_Income level:
# Family_Income             High       Low    Medium
# Parental_Involvement
# High                  0.290780  0.287425  0.289197
# Low                   0.197794  0.213698  0.193173
# Medium                0.511426  0.498877  0.517629

# %% [markdown]
# **3. relationship between the number of sleep hours and class attendance**

# %%
print("Relationship between Sleep_Hours and Attendance:")

plt.figure(figsize=(8, 5))
sns.scatterplot(x='Sleep_Hours', y='Attendance', data=df)
plt.title('Attendance vs. Sleep Hours')
plt.xlabel('Sleep Hours')
plt.ylabel('Attendance')
plt.show()

correlation_sleep_attendance = df['Sleep_Hours'].corr(df['Attendance'])
print(f"\nCorrelation coefficient between Sleep_Hours and Attendance: {correlation_sleep_attendance:.2f}")
# Out:
# Relationship between Sleep_Hours and Attendance:
# Correlation coefficient between Sleep_Hours and Attendance: -0.02

# %% [markdown]
# `There is NO`

# %% [markdown]
# **4. Grades differ for boys and girls living at different distances from school?**

# %%
# Question 4: How do grades differ for boys and girls living at different distances from school?

# Research Task: Examine the differences in Exam_Score based on Gender and Distance_from_Home.
# Variables: Exam_Score (Ratio), Gender (Nominal), Distance_from_Home (Ordinal)
# Method: Grouped box plots and descriptive statistics by groups.

print("Descriptive Statistics for Exam_Score by Gender and Distance_from_Home:")
display(df.groupby(['Gender', 'Distance_from_Home'])['Exam_Score'].describe())

# Create grouped box plots
plt.figure(figsize=(10, 7))
sns.boxplot(x='Distance_from_Home', y='Exam_Score', hue='Gender', data=df, order=['Near', 'Moderate', 'Far'])
plt.title('Exam Score by Distance from Home and Gender')
plt.xlabel('Distance from Home')
plt.ylabel('Exam Score')
plt.show()

# Interpretation:
# - Tabel statistik deskriptif menunjukkan rata-rata, median, sebaran, dll. dari nilai ujian untuk setiap kombinasi jenis kelamin dan jarak dari rumah.
# - Grafik box plot yang dikelompokkan secara visual membandingkan distribusi nilai ujian untuk siswa laki-laki dan perempuan dalam setiap kategori jarak dari rumah. Kita dapat mengamati perbedaan dalam median, rentang interkuartil, dan outlier antara kelompok-kelompok ini.
# - Dari kedua output ini, kita dapat menarik kesimpulan deskriptif tentang bagaimana nilai ujian berbeda berdasarkan jenis kelamin dan jarak tempat tinggal siswa dari sekolah.
# Out:
# Descriptive Statistics for Exam_Score by Gender and Distance_from_Home:
#                             count       mean       std   min   25%   50%  \
# Gender Distance_from_Home
# Female Far                  281.0  66.153025  3.958003  57.0  63.0  66.0
#        Moderate             837.0  66.917563  3.900269  58.0  64.0  67.0
#        Near                1644.0  67.615572  4.114538  57.0  65.0  67.0
# Male   Far                  377.0  66.684350  4.269959  56.0  64.0  66.0
#        Moderate            1161.0  67.027562  3.704740  57.0  65.0  67.0
#        Near                2240.0  67.436161  3.700299  55.0  65.0  67.0
#
#                             75%    max
# Gender Distance_from_Home
# Female Far                 68.0   94.0
#        Moderate            69.0  101.0
#        Near                70.0  100.0
# Male   Far                 69.0   99.0
#        Moderate            69.0   94.0
#        Near                70.0   98.0

# %% [markdown]
# **5. What are the specific characteristics of distribution of final exam grades?**

# %%
print("Descriptive Statistics for Exam_Score:")
display(df['Exam_Score'].describe())

print(f"\nSkewness: {df['Exam_Score'].skew():.2f}")
print(f"Kurtosis: {df['Exam_Score'].kurtosis():.2f}")

plt.figure(figsize=(8, 5))
sns.histplot(df['Exam_Score'], kde=True)
plt.title('Distribution of Exam Scores')
plt.xlabel('Exam Score')
plt.ylabel('Frequency')
plt.show()
# Out:
# Descriptive Statistics for Exam_Score:
# count    6607.000000
# mean       67.235659
# std         3.890456
# min        55.000000
# 25%        65.000000
# 50%        67.000000
# 75%        69.000000
# max       101.000000
# Name: Exam_Score, dtype: float64
# Skewness: 1.64
# Kurtosis: 10.58

# %% [markdown]
# **6. Is there a relationship between the level of students' motivation and the quality of teaching?**

# %%
print("Frequency table of Motivation_Level by Teacher_Quality:")

cross_tab_motivation_teacher = pd.crosstab(df['Motivation_Level'], df['Teacher_Quality'])
display(cross_tab_motivation_teacher)


print("\nProportion of Teacher_Quality within each Motivation_Level:")
cross_tab_motivation_teacher_prop = pd.crosstab(df['Motivation_Level'], df['Teacher_Quality'], normalize='index')
display(cross_tab_motivation_teacher_prop)

cross_tab_motivation_teacher_prop.plot(kind='bar', stacked=True, figsize=(10, 7))
plt.title('Proportion of Teacher Quality by Student Motivation Level')
plt.xlabel('Motivation Level')
plt.ylabel('Proportion of Students')
plt.xticks(rotation=0)
plt.legend(title='Teacher Quality', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# Frequency table of Motivation_Level by Teacher_Quality:
# Teacher_Quality   High  Low  Medium
# Motivation_Level
# High               405  134     767
# Low                582  156    1173
# Medium             960  367    1985
# Proportion of Teacher_Quality within each Motivation_Level:
# Teacher_Quality       High       Low    Medium
# Motivation_Level
# High              0.310107  0.102603  0.587289
# Low               0.304553  0.081633  0.613815
# Medium            0.289855  0.110809  0.599336

# %% [markdown]
# `Not Significant`

# %% [markdown]
# **7. What are the characteristics of excellent students (please define and describe which students should be classified as excellent)?**

# %% [markdown]
# Student with Good Exam Score with Participation of Extracurricular and high Hours Studied

# %%
print("Relationship between Exam_Score, Hours_Studied, and Extracurricular_Activities:")

plt.figure(figsize=(10, 6))
sns.scatterplot(x='Hours_Studied', y='Exam_Score', hue='Extracurricular_Activities', data=df)
plt.title('Exam Score vs. Hours Studied by Extracurricular Activities')
plt.xlabel('Hours Studied')
plt.ylabel('Exam Score')
plt.legend(title='Extracurricular Activities')
plt.show()
# Out:
# Relationship between Exam_Score, Hours_Studied, and Extracurricular_Activities:

# %% [markdown]
# **8. Which factors are positively correlated with exam results t**

# %%
print("Descriptive Measures of Association with Exam_Score for ALL Variables:")
numerical_vars = df.select_dtypes(include=np.number).columns.tolist()
numerical_vars.remove('Exam_Score')

print("\nCorrelation Coefficients with Exam_Score (for Numerical Variables):")
for var in numerical_vars:
    correlation = df[var].corr(df['Exam_Score'])
    print(f"Correlation between {var} and Exam_Score: {correlation:.2f}")

print("\nMean Exam_Score across Categories (for Categorical Variables):")

categorical_vars = df.select_dtypes(include=['object', 'category']).columns.tolist()

for var in categorical_vars:
    print(f"\nMean Exam_Score by {var}:")
    mean_exam_by_category = df.groupby(var, dropna=False)['Exam_Score'].mean()
    print(mean_exam_by_category)
# Out:
# Descriptive Measures of Association with Exam_Score for ALL Variables:
#
# Correlation Coefficients with Exam_Score (for Numerical Variables):
# Correlation between Hours_Studied and Exam_Score: 0.45
# Correlation between Attendance and Exam_Score: 0.58
# Correlation between Sleep_Hours and Exam_Score: -0.02
# Correlation between Previous_Scores and Exam_Score: 0.18
# Correlation between Tutoring_Sessions and Exam_Score: 0.16
# Correlation between Physical_Activity and Exam_Score: 0.03
#
# Mean Exam_Score across Categories (for Categorical Variables):
#
# Mean Exam_Score by Parental_Involvement:
# Parental_Involvement
# High      68.092767
# Low       66.358265
# Medium    67.098156
# Name: Exam_Score, dtype: float64
#
# Mean Exam_Score by Access_to_Resources:
# Access_to_Resources
# High      68.092152
# Low       66.203351
# Medium    67.134378
# Name: Exam_Score, dtype: float64
#
# Mean Exam_Score by Extracurricular_Activities:
# Extracurricular_Activities
# No     66.931435
# ...

# %% [markdown]
# `28-44 Hours Studied have the most positive impact on Exam Results`

# %% [markdown]
# **9. Which variables have a distribution close to normal, explain your answer?**

# %%
numerical_vars = df.select_dtypes(include=np.number).columns.tolist()
if 'Hours_Studied_Range' in numerical_vars:
    numerical_vars.remove('Hours_Studied_Range')

print("\nSkewness and Kurtosis for Numerical Variables:")
for var in numerical_vars:
    skewness = df[var].skew()
    kurtosis = df[var].kurtosis()
    print(f"{var}: Skewness={skewness:.2f}, Kurtosis={kurtosis:.2f}")

print("\nHistograms for Numerical Variables:")
for var in numerical_vars:
    plt.figure(figsize=(8, 5))
    sns.histplot(df[var], kde=True)
    plt.title(f'Distribution of {var}')
    plt.xlabel(var)
    plt.ylabel('Frequency')
    plt.show()
# Out:
# Skewness and Kurtosis for Numerical Variables:
# Hours_Studied: Skewness=0.01, Kurtosis=0.02
# Attendance: Skewness=0.01, Kurtosis=-1.19
# Sleep_Hours: Skewness=-0.02, Kurtosis=-0.50
# Previous_Scores: Skewness=-0.00, Kurtosis=-1.19
# Tutoring_Sessions: Skewness=0.82, Kurtosis=0.64
# Physical_Activity: Skewness=-0.03, Kurtosis=-0.06
# Exam_Score: Skewness=1.64, Kurtosis=10.58
#
# Histograms for Numerical Variables:

# %% [markdown]
# -Hours_Studied: Skewness (0.01) and kurtosis (0.02) are very close to 0. The histogram also appears quite symmetrical and bell-shaped.
#
# -Physical_Activity: Skewness (-0.03) and kurtosis (-0.06) are also very close to 0. The histogram appears relatively symmetrical, although somewhat uniform in shape across some values.
#
# -Other variables, such as Attendance and Previous_Scores, have skewness close to 0, but their kurtosis is quite negative (-1.19), indicating a distribution that is flatter (platykurtic) than normal.
#
# -Sleep_Hours has skewness close to 0 but negative kurtosis (-0.50).

# %% [markdown]
# **10. Which metric variables have an asymmetry in the distribution of their values?**

# %% [markdown]
# -Tutoring_Sessions and Exam_Score have skewness and kurtosis that are further from 0, indicating asymmetry and/or tailedness that differs from a normal distribution.

# %% [markdown]
# **DATA ANALYST HOMEWORK 6/09/2025 - 10/09/2025**

# %% [markdown]
# Comments on the task and principles of its assessment:
#
# - All points of the task must be accompanied by _executed_ code fragments.
# - All results of the code execution (statistics, graphs, tables) should be commented, conclusions in the written form should be made based on them.
# - If you have completed this task, you will receive 8 points (excellent grade). To get a higher grade (9 or 10), you need to go beyond the proposed task. For example, use additional descriptive data analysis methods and instruments, which were not discussed in the class.
# - This task consists of three parts. The first weighs 10%, the second - 40%, the third - 50%.
# - The task can be completed individually or in a group of 2 students, the assessment criteria will be the same.
# - If the task is completed by 2 students, then only one of the students should upload the work to SmartLMS.
# - The name of the file uploaded to SmartLMS should include the last name(s) of the author(s) of the work.
# - If you use AI in the work, you must indicate where and how exactly it was used.

# %% [markdown]
# ### Please upload the Jupyter Notebook with comments and answers in SmartLMS. The deadline is 10 September 23:55.
